# %%
# !pip install pandas
# !pip install numpy
# Out:
# ...
#   Using cached pandas-2.0.3-cp38-cp38-macosx_10_9_x86_64.whl.metadata (18 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached numpy-1.24.4-cp38-cp38-macosx_10_9_x86_64.whl.metadata (5.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 8.3 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.8/19.8 MB 9.4 MB/s eta 0:00:0000:0100:01
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# ...

# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0    148.0           72.0           35.0      0.0  33.6
# 1            1.0     85.0           66.0           29.0      0.0  26.6
# 2            8.0    183.0           64.0            0.0      0.0  23.3
# 3            1.0     89.0           66.0           23.0     94.0  28.1
# 4            0.0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763         10.0    101.0           76.0           48.0    180.0  32.9
# 764          2.0    122.0           70.0            NaN      0.0  36.8
# 765          5.0    121.0           72.0           23.0    112.0  26.2
# 766          1.0    126.0           60.0            0.0      0.0  30.1
# 767          1.0     93.0           70.0           31.0      0.0  30.4
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.627  50.0        1
# ...

# %%
df.dtypes
# Out:
# Pregnancies                 float64
# Glucose                     float64
# BloodPressure               float64
# SkinThickness               float64
# Insulin                     float64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                         float64
# Outcome                       int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0      0.0  33.6
# 1          1.0     85.0           66.0           29.0      0.0  26.6
# 2          8.0    183.0           64.0            0.0      0.0  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          0.0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.627  50.0        1
# 1                     0.351  31.0        0
# 2                     0.672  32.0        1
# 3                     0.167  21.0        0
# 4                     2.288  33.0        1

# %%
df.tail(5)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763         10.0    101.0           76.0           48.0    180.0  32.9
# 764          2.0    122.0           70.0            NaN      0.0  36.8
# 765          5.0    121.0           72.0           23.0    112.0  26.2
# 766          1.0    126.0           60.0            0.0      0.0  30.1
# 767          1.0     93.0           70.0           31.0      0.0  30.4
#
#      DiabetesPedigreeFunction   Age  Outcome
# 763                     0.171  63.0        0
# 764                     0.340  27.0        0
# 765                     0.245  30.0        0
# 766                     0.349  47.0        1
# 767                     0.315  23.0        0

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   767.000000  765.000000     765.000000     766.000000  765.000000
# mean      3.846154  120.916340      69.075817      20.502611   79.841830
# std       3.371638   32.017065      19.378147      15.955801  115.306034
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   32.000000
# 75%       6.000000  141.000000      80.000000      32.000000  127.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  766.000000                766.000000  767.000000  768.000000
# mean    31.973499                  0.472269   33.249022    0.348958
# std      7.879620                  0.331671   11.765742    0.476951
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 1
# Glucose                     3
# BloodPressure               3
# SkinThickness               2
# Insulin                     3
# BMI                         2
# DiabetesPedigreeFunction    2
# Age                         1
# Outcome                     0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Pregnancies                 1
# Glucose                     3
# BloodPressure               3
# SkinThickness               2
# Insulin                     3
# BMI                         2
# DiabetesPedigreeFunction    2
# Age                         1
# Outcome                     0
# dtype: int64

# %%
with_diabetes=df[df['Outcome']==1]
with_diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0    148.0           72.0           35.0      0.0  33.6
# 2            8.0    183.0           64.0            0.0      0.0  23.3
# 4            0.0    137.0           40.0           35.0    168.0  43.1
# 6            3.0     78.0           50.0           32.0     88.0  31.0
# 8            2.0    197.0           70.0           45.0    543.0  30.5
# ..           ...      ...            ...            ...      ...   ...
# 755          1.0    128.0           88.0           39.0    110.0  36.5
# 757          0.0    123.0           72.0            0.0      0.0  36.3
# 759          6.0    190.0           92.0            0.0      0.0  35.5
# 761          9.0    170.0           74.0           31.0      0.0  44.0
# 766          1.0    126.0           60.0            0.0      0.0  30.1
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.627  50.0        1
# ...

# %%
without_diabetes=df[df['Outcome']==0]
without_diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1            1.0     85.0           66.0           29.0      0.0  26.6
# 3            1.0     89.0           66.0           23.0     94.0  28.1
# 5            5.0      NaN           74.0            0.0      0.0  25.6
# 7           10.0    115.0            0.0            0.0      0.0  35.3
# 10           4.0    110.0           92.0            0.0      0.0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 762          9.0     89.0           62.0            0.0      0.0  22.5
# 763         10.0    101.0           76.0           48.0    180.0  32.9
# 764          2.0    122.0           70.0            NaN      0.0  36.8
# 765          5.0    121.0           72.0           23.0    112.0  26.2
# 767          1.0     93.0           70.0           31.0      0.0  30.4
#
#      DiabetesPedigreeFunction   Age  Outcome
# 1                       0.351  31.0        0
# ...

# %%
# !pip install matplotlib
# !pip install seaborn
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.2/162.2 kB 1.3 MB/s eta 0:00:00a 0:00:01
# ...
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 10.3 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.0/247.0 kB 7.6 MB/s eta 0:00:00
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 11.0 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.0/68.0 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 10.6 MB/s eta 0:00:00a 0:00:01
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# Insuline and Glucose levels of people with Diabetes

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(with_diabetes[['Glucose', 'Insulin']], palette=['#25573e', '#de7850'])
plt.xlabel('Glucose and Insulin levels', color='#80cba4')
plt.ylabel('Count', color='#80cba4')
plt.title('People with Diabetes', fontsize=20, color='Red')
# Out:
# Text(0.5, 1.0, 'People with Diabetes')

# %% [markdown]
# Insuline and glucose levels of people without Diabetes

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(without_diabetes[['Glucose', 'Insulin']], palette=['#25573e', '#de7850'])
plt.xlabel('Glucose and Insulin levels', color='#80cba4')
plt.ylabel('Count', color='#80cba4')
plt.title('People without Diabetes', fontsize=20, color='Red')
# Out:
# Text(0.5, 1.0, 'People without Diabetes')
